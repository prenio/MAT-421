# %% [markdown]
# <a href="https://colab.research.google.com/github/prenio/MAT-421/blob/main/MAT_421_Module_H_22_4%2C_22_5%2C_22_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>MAT 421: Module H</h1>
# <h2>Sections: 22.4, 22.5, 22.6</h2>

# %% [markdown]
# <u>Question:</u> Consider the ODE<br>
#         dS(t)/dt = sin(t)<br>
# for an initial value S<sub>0</sub> = 0. The exact solution to this problem is S(t) = -cos(t). Use the solve_ivp method to approximate the solution to the initial value problem over the interval |0,π|.

# %% [markdown]
# <p>Import needed libraries</p>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import solve_ivp

plt.style.use('seaborn-poster')

function = lambda t, s: np.sin(t)

t_eval = np.arange(0, np.pi, 0.1)
solution = solve_ivp(function, [0, np.pi], [0], t_eval=t_eval)

print(solution)
# Out:
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  1.000e-01 ...  3.000e+00  3.100e+00]
#         y: [[ 0.000e+00  4.996e-03 ...  1.990e+00  1.999e+00]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 38
#      njev: 0
#       nlu: 0
# <ipython-input-27-4b87d05d9ab9>:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %% [markdown]
# <u>Question:</u> Plot the difference between the approximated solution versus the exact solution and the relative error over time from the previous problem.

# %%
plt.figure(figsize = (12, 4))
plt.subplot(121)
plt.plot(solution.t, solution.y[0])
plt.xlabel('t')
plt.ylabel('S(t)')
plt.subplot(122)
plt.plot(solution.t, solution.y[0] + np.cos(solution.t))
plt.xlabel('t')
plt.ylabel('S(t) + cos(t)')
plt.tight_layout()
plt.show()
